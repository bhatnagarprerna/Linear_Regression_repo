# %% [markdown]
# # Application of Analytics

# %% [markdown]
# # Problem Statement
# 1. EDA, some insights, presented neatly.
# 2. The training and testing accuracy of your model. So do split the data before modelling.
#
# ![](https://media.tenor.com/mUVjXo5LhsQAAAAC/kakashi-yes.gif)

# %%
import pandas as pd

# %%
df= pd.read_csv("hardware.csv")

# %%
df
# Out:
#       CATEGORY_ID CATEGORY_NAME  PRODUCT_ID               PRODUCT_NAME  \
# 0               1           CPU           8      Intel Xeon E5-1650 V4
# 1               1           CPU           8      Intel Xeon E5-1650 V4
# 2               1           CPU           8      Intel Xeon E5-1650 V4
# 3               1           CPU           8      Intel Xeon E5-1650 V4
# 4               1           CPU           8      Intel Xeon E5-1650 V4
# ...           ...           ...         ...                        ...
# 1107            5       Storage         273  Western Digital WD101KRYZ
# 1108            5       Storage         273  Western Digital WD101KRYZ
# 1109            5       Storage         273  Western Digital WD101KRYZ
# 1110            5       Storage         273  Western Digital WD101KRYZ
# 1111            5       Storage         273  Western Digital WD101KRYZ
#
#                                             DESCRIPTION  \
# 0                         Speed:3.6GHz,Cores:6,TDP:140W
# ...

# %% [markdown]
# ![](https://media.tenor.com/zuYC6pvC9FoAAAAM/let-us-begin.gif)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1112 entries, 0 to 1111
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CATEGORY_ID             1112 non-null   int64
#  1   CATEGORY_NAME           1112 non-null   object
#  2   PRODUCT_ID              1112 non-null   int64
#  3   PRODUCT_NAME            1112 non-null   object
#  4   DESCRIPTION             1112 non-null   object
#  5   DESCRIPTION - Detail 1  1112 non-null   object
#  6   DESCRIPTION - Detail 2  1112 non-null   object
#  7   DESCRIPTION - Detail 3  794 non-null    object
#  8   DESCRIPTION - Detail 4  350 non-null    object
#  9   STANDARD_COST           1112 non-null   float64
#  10  LIST_PRICE              1112 non-null   float64
#  11  COUNTRY_ID              1112 non-null   object
#  12  REGION_ID               1112 non-null   int64
#  13  LOCATION_ID             1112 non-null   int64
# ...

# %%
print(df.describe())
# Out:
#        CATEGORY_ID   PRODUCT_ID  STANDARD_COST   LIST_PRICE    REGION_ID  \
# count  1112.000000  1112.000000    1112.000000  1112.000000  1112.000000
# mean      3.203237   139.579137     765.520405   950.993327     2.469424
# std       1.637782    84.840057     794.252142   991.070482     0.499289
# min       1.000000     2.000000      12.630000    15.550000     2.000000
# 25%       2.000000    71.750000     332.380000   435.222500     2.000000
# 50%       4.000000   133.000000     582.020000   744.980000     2.000000
# 75%       5.000000   216.000000     799.050000   999.990000     3.000000
# max       5.000000   288.000000    7123.660000  8867.990000     3.000000
#
#        LOCATION_ID  WAREHOUSE_ID     QUANTITY
# count  1112.000000   1112.000000  1112.000000
# mean     10.971223      5.548561   107.474820
# std       4.662225      2.416821    68.008413
# min       5.000000      1.000000     0.000000
# 25%       8.000000      4.000000    50.000000
# ...

# %%
print(df.isnull().sum())
# Out:
# CATEGORY_ID                 0
# CATEGORY_NAME               0
# PRODUCT_ID                  0
# PRODUCT_NAME                0
# DESCRIPTION                 0
# DESCRIPTION - Detail 1      0
# DESCRIPTION - Detail 2      0
# DESCRIPTION - Detail 3    318
# DESCRIPTION - Detail 4    762
# STANDARD_COST               0
# LIST_PRICE                  0
# COUNTRY_ID                  0
# REGION_ID                   0
# LOCATION_ID                 0
# WAREHOUSE_ID                0
# QUANTITY                    0
# WAREHOUSE_NAME              0
# ADDRESS                     0
# POSTAL_CODE                 0
# CITY                        0
# STATE                       0
# COUNTRY_NAME                0
# dtype: int64

# %%
hardware = df.dropna(axis=1)

# %%
print(hardware.isnull().sum())
# Out:
# CATEGORY_ID               0
# CATEGORY_NAME             0
# PRODUCT_ID                0
# PRODUCT_NAME              0
# DESCRIPTION               0
# DESCRIPTION - Detail 1    0
# DESCRIPTION - Detail 2    0
# STANDARD_COST             0
# LIST_PRICE                0
# COUNTRY_ID                0
# REGION_ID                 0
# LOCATION_ID               0
# WAREHOUSE_ID              0
# QUANTITY                  0
# WAREHOUSE_NAME            0
# ADDRESS                   0
# POSTAL_CODE               0
# CITY                      0
# STATE                     0
# COUNTRY_NAME              0
# dtype: int64

# %% [markdown]
# ## Univariate Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('darkgrid')
sns.countplot(x="CATEGORY_NAME", data=hardware,palette='rocket')
# Out:
# <AxesSubplot:xlabel='CATEGORY_NAME', ylabel='count'>

# %%
plt.figure(figsize=(8,6))
plt.boxplot(hardware['LIST_PRICE'])
plt.title('Box plot of Price', fontsize=14)
plt.xlabel('Price', fontsize=12)
plt.show()

# %%
sns.histplot(hardware['STANDARD_COST'], kde=False, color='blue')
plt.xlabel('Standard Cost')
plt.ylabel('Frequency')
plt.title('Distribution of Standard Cost')
plt.show()

# %%
sns.countplot(hardware['CATEGORY_NAME'], palette='muted')
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Distribution of Categories')
plt.show()
# Out:
# C:\Users\Prerna Bhatnagar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.kdeplot(hardware["LIST_PRICE"], shade=True, color="green")
plt.xlabel("List Price")
plt.title("KDE Plot of List Price")
plt.show()

# %%
sns.histplot(data=hardware, x='WAREHOUSE_NAME',color='purple')
plt.xticks(rotation=75)
plt.show()

# %%
colors = ["#7fb3d5", "#f7b6d2", "#c7e9c0", "#fccde5", "#a1d99b", "#fed98e", "#9ecae1", "#fb9a99"]
plt.figure(figsize=(8, 8))
hardware_country = hardware.groupby("COUNTRY_NAME").size().reset_index(name="Count")
plt.pie(hardware_country["Count"], labels=hardware_country["COUNTRY_NAME"], colors=colors, autopct='%1.1f%%')
plt.title("Proportion of Products by Country", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Proportion of Products by Country')

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.barplot(data=hardware, x='COUNTRY_NAME', y='QUANTITY', palette='viridis')
plt.title('Quantity by Country')
plt.xlabel('Country')
plt.ylabel('Quantity')
plt.xticks(rotation=60)
plt.show()

# %%
sns.scatterplot(data=hardware, x='STANDARD_COST', y='LIST_PRICE', hue='CATEGORY_NAME', palette='Set1')
# Out:
# <AxesSubplot:xlabel='STANDARD_COST', ylabel='LIST_PRICE'>

# %%
sns.boxplot(x="REGION_ID", y="STANDARD_COST", data=hardware,palette='icefire')
plt.title("Standard Cost by Region", fontsize=16)
plt.xlabel("Region ID", fontsize=14)
plt.ylabel("Standard Cost", fontsize=14)
# Out:
# Text(0, 0.5, 'Standard Cost')

# %% [markdown]
# #### The median standard cost is highest for Region 2. Region 3 have the lowest median standard cost values.

# %%
sns.swarmplot(x='CATEGORY_NAME', y='LIST_PRICE', data=hardware, color='purple')
# Out:
# C:\Users\Prerna Bhatnagar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 54.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Prerna Bhatnagar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 66.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Prerna Bhatnagar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 73.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Prerna Bhatnagar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 75.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x='REGION_ID', y='LIST_PRICE', data=df, palette='Blues_r')
plt.title('List Price by Region')
plt.xlabel('Region')
plt.ylabel('List Price')
plt.show()

# %% [markdown]
# #### It appears that region 3 has the highest median list price

# %%
sns.catplot(x='WAREHOUSE_NAME', y='QUANTITY', data=df, kind='bar')
plt.xticks(rotation=90)
plt.title('Quantity of Products in each Warehouse')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=hardware['LIST_PRICE'], y=hardware['QUANTITY'], alpha=0.7, color='blue')
plt.title('Scatter plot of Price vs Quantity', fontsize=14)
plt.xlabel('Price', fontsize=12)
plt.ylabel('Quantity', fontsize=12)
plt.show()

# %% [markdown]
# #### The plot suggests a weak positive correlation between list price and quantity, with some variability in the relationship.

# %%
sns.stripplot(data=hardware, x='CATEGORY_NAME', y='LIST_PRICE', hue='COUNTRY_NAME', palette='magma')
plt.title('List Price by Category and Country')
plt.xlabel('Category')
plt.ylabel('List Price')
plt.show()

# %% [markdown]
# #### "CPU" and "Video Card" have a wider range of list prices compared to other categories.

# %%
sns.heatmap(hardware.corr(), annot=True)
plt.show()

# %% [markdown]
# #### The LIST_PRICE  is strongly correlated with the STANDARD_COST .The PRODUCT_ID and CATEGORY_ID variables are not strongly correlated with any other variables.

# %% [markdown]
# ## WordCloud

# %%
from wordcloud import WordCloud
countries = ' '.join(hardware['COUNTRY_NAME'])

# Generate a wordcloud image
wordcloud = WordCloud(width=800, height=400, background_color="green",colormap='magma').generate(countries)

# Display the generated image
plt.figure(figsize=(12, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# #### Major products were sold in United States followed by Australia and other countries

# %% [markdown]
# ## The Real game starts here

# %% [markdown]
# ![](https://media.tenor.com/89pNY5CDNNQAAAAM/this-is-when-fun-begins-fun-begins.gif)

# %%
data = hardware.drop(['CATEGORY_ID','PRODUCT_NAME','DESCRIPTION','PRODUCT_ID','REGION_ID','COUNTRY_ID','LOCATION_ID','WAREHOUSE_ID','ADDRESS','POSTAL_CODE'],axis=1)

# %%
data
# Out:
#      CATEGORY_NAME DESCRIPTION - Detail 1 DESCRIPTION - Detail 2  \
# 0              CPU           Speed:3.6GHz                Cores:6
# 1              CPU           Speed:3.6GHz                Cores:6
# 2              CPU           Speed:3.6GHz                Cores:6
# 3              CPU           Speed:3.6GHz                Cores:6
# 4              CPU           Speed:3.6GHz                Cores:6
# ...            ...                    ...                    ...
# 1107       Storage            Series:Gold           Type:7200RPM
# 1108       Storage            Series:Gold           Type:7200RPM
# 1109       Storage            Series:Gold           Type:7200RPM
# 1110       Storage            Series:Gold           Type:7200RPM
# 1111       Storage            Series:Gold           Type:7200RPM
#
#       STANDARD_COST  LIST_PRICE  QUANTITY       WAREHOUSE_NAME  \
# 0            535.47      601.99        50              Beijing
# ...

# %%
list_of_categorical_columns =  data.select_dtypes(include=['object']).columns

# %%
list_of_categorical_columns
# Out:
# Index(['CATEGORY_NAME', 'DESCRIPTION - Detail 1', 'DESCRIPTION - Detail 2',
#        'WAREHOUSE_NAME', 'CITY', 'STATE', 'COUNTRY_NAME'],
#       dtype='object')

# %% [markdown]
# ## Convert categories into numbers - Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in list_of_categorical_columns:
    data[i]=le.fit_transform(data[i])

# %%
data
# Out:
#       CATEGORY_NAME  DESCRIPTION - Detail 1  DESCRIPTION - Detail 2  \
# 0                 0                      71                       7
# 1                 0                      71                       7
# 2                 0                      71                       7
# 3                 0                      71                       7
# 4                 0                      71                       7
# ...             ...                     ...                     ...
# 1107              2                      47                      49
# 1108              2                      47                      49
# 1109              2                      47                      49
# 1110              2                      47                      49
# 1111              2                      47                      49
#
#       STANDARD_COST  LIST_PRICE  QUANTITY  WAREHOUSE_NAME  CITY  STATE  \
# 0            535.47      601.99        50               0     0      6
# ...

# %%
x=data[['CATEGORY_NAME','DESCRIPTION - Detail 1','DESCRIPTION - Detail 2','STANDARD_COST','QUANTITY','WAREHOUSE_NAME','CITY','STATE','COUNTRY_NAME']]

# %%
y=data['LIST_PRICE']

# %% [markdown]
# # Train and Test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.2)

# %%
print(len(x_train))
print(len(x_test))
print(len(y_train))
print(len(y_test))
# Out:
# 889
# 223
# 889
# 223

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
len(y_test)
# Out:
# 223

# %%
len(y_pred)
# Out:
# 223

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
mse = mean_squared_error(y_test,y_pred)

# %%
rsq = r2_score(y_test,y_pred)

# %%
print('mean squared error :',mse)
print('r square :',rsq)
# Out:
# mean squared error : 5814.988590139142
# r square : 0.9935516810689574

# %% [markdown]
# ![](https://media.tenor.com/visJrdbmUQYAAAAM/i-cant-function-the-black-hokage.gif)
